# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/MLOM/Labs/Lab 09/diabetes.csv")
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# declare X (features) and y (labels) arrays

# %%
#data preperation
x = data.iloc[:,:8].values

# %%
x
# Out:
# array([[  6.   , 148.   ,  72.   , ...,  33.6  ,   0.627,  50.   ],
#        [  1.   ,  85.   ,  66.   , ...,  26.6  ,   0.351,  31.   ],
#        [  8.   , 183.   ,  64.   , ...,  23.3  ,   0.672,  32.   ],
#        ...,
#        [  5.   , 121.   ,  72.   , ...,  26.2  ,   0.245,  30.   ],
#        [  1.   , 126.   ,  60.   , ...,  30.1  ,   0.349,  47.   ],
#        [  1.   ,  93.   ,  70.   , ...,  30.4  ,   0.315,  23.   ]])

# %%
y = data.iloc[:,8]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=0)

# %%
# Create an SVC model
model = SVC(C=1.0, kernel = 'linear')

#if linear separatable : linear
#if non linear :  poly

# %%
# Train the model
model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)

# %%
# Evaluate the model's accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8181818181818182

# %% [markdown]
# ## To find Confusion Matrix and Classification Report

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.91      0.87       107
#            1       0.74      0.62      0.67        47
#
#     accuracy                           0.82       154
#    macro avg       0.79      0.76      0.77       154
# weighted avg       0.81      0.82      0.81       154

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[97, 10],
#        [18, 29]])

# %%
#for cross validation
scores = cross_val_score(model, X_train, y_train, cv=5)  # 5-fold cross-validation

# %%
scores
# Out:
# array([0.73170732, 0.80487805, 0.74796748, 0.71544715, 0.79508197])

# %%
#Calculate the average accuracy and any other relevant statistics from the scores
mean_accuracy = scores.mean()
std_deviation = scores.std()

# %%
mean_accuracy
# Out:
# 0.759016393442623
